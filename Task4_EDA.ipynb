# %%
import numpy as np
import pandas as pd
# For visualizations
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing dataset
data=pd.read_csv('C:/Users/a/Desktop/SampleSuperstore.csv') 
print("Shape of data=>",data.shape)
# Out:
# Shape of data=> (9994, 13)

# %%
data
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 0       Second Class   Consumer  United States    Henderson    Kentucky
# 1       Second Class   Consumer  United States    Henderson    Kentucky
# 2       Second Class  Corporate  United States  Los Angeles  California
# ...              ...        ...            ...          ...         ...
# 9991  Standard Class   Consumer  United States   Costa Mesa  California
# 9992  Standard Class   Consumer  United States   Costa Mesa  California
# 9993    Second Class   Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.960         2
# 1           42420  South        Furniture       Chairs  731.940         3
# 2           90036   West  Office Supplies       Labels   14.620         2
# ...           ...    ...              ...          ...      ...       ...
# ...

# %%
# Let's try to read from the superstore.csv
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 7)

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 702.8+ KB

# %%
# Let's try to change the datatypes of the following column in the dataset.

#data['Ship Date'] = data['Ship Date'].astype('datetime64[ns]')
#data['Postal Code'] = data['Postal Code'].astype('object')
data.describe(include='all')
# Out:
#              Ship Mode   Segment        Country           City       State  \
# count             9994      9994           9994           9994        9994
# unique               4         3              1            531          49
# top     Standard Class  Consumer  United States  New York City  California
# ...                ...       ...            ...            ...         ...
# 50%                NaN       NaN            NaN            NaN         NaN
# 75%                NaN       NaN            NaN            NaN         NaN
# max                NaN       NaN            NaN            NaN         NaN
#
#         Postal Code Region         Category Sub-Category     Sales  Quantity  \
# count        9994.0   9994             9994         9994   9994.00    9994.0
# unique          NaN      4                3           17       NaN       NaN
# top             NaN   West  Office Supplies      Binders       NaN       NaN
# ...

# %%
# Let's create a class named `display_all`, by which later we call on the next command.
def display_all(data):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000):
        display(data)

# %%
display_all(data.head(5).T)
# Out:
#                           0              1                2                3  \
# Ship Mode      Second Class   Second Class     Second Class   Standard Class
# Segment            Consumer       Consumer        Corporate         Consumer
# Country       United States  United States    United States    United States
# City              Henderson      Henderson      Los Angeles  Fort Lauderdale
# State              Kentucky       Kentucky       California          Florida
# Postal Code           42420          42420            90036            33311
# Region                South          South             West            South
# Category          Furniture      Furniture  Office Supplies        Furniture
# Sub-Category      Bookcases         Chairs           Labels           Tables
# Sales                261.96         731.94            14.62          957.577
# Quantity                  2              3                2                5
# ...

# %%
display_all(data.describe(include='all').T)
# Out:
#              count unique              top  freq      mean       std      min  \
# Ship Mode     9994      4   Standard Class  5968       NaN       NaN      NaN
# Segment       9994      3         Consumer  5191       NaN       NaN      NaN
# Country       9994      1    United States  9994       NaN       NaN      NaN
# City          9994    531    New York City   915       NaN       NaN      NaN
# State         9994     49       California  2001       NaN       NaN      NaN
# Postal Code   9994    NaN              NaN   NaN   55190.4   32063.7     1040
# Region        9994      4             West  3203       NaN       NaN      NaN
# Category      9994      3  Office Supplies  6026       NaN       NaN      NaN
# Sub-Category  9994     17          Binders  1523       NaN       NaN      NaN
# Sales         9994    NaN              NaN   NaN   229.858   623.245    0.444
# Quantity      9994    NaN              NaN   NaN   3.78957   2.22511        1
# ...

# %%
plt.figure(figsize=(9,8))
sns.distplot(data['Profit'],color='g',bins=100,hist_kws={'alpha':0.4})

# %%
data_num=data.select_dtypes(include=['float64','int64'])

# %%
data_num
# Out:
#       Postal Code    Sales  Quantity  Discount    Profit
# 0           42420  261.960         2       0.0   41.9136
# 1           42420  731.940         3       0.0  219.5820
# 2           90036   14.620         2       0.0    6.8714
# ...           ...      ...       ...       ...       ...
# 9991        92627  258.576         2       0.2   19.3932
# 9992        92627   29.600         4       0.0   13.3200
# 9993        92683  243.160         2       0.0   72.9480
#
# [9994 rows x 5 columns]

# %%
data_num.hist(figsize=(16,20),bins=50,xlabelsize=8,ylabelsize=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x16701D48>,
# ...
#       dtype=object)

# %%
#to find the correlation
data_num_corr=data_num.corr()['Profit'][::-1]
golden_features_list=data_num_corr[abs(data_num_corr)>0.5].sort_values(ascending=False)
print('There are {} strongly correlated values with Profit:\n{}'.format(len(golden_features_list),
                                                                       golden_features_list))
# Out:
# There are 1 strongly correlated values with Profit:
# Profit    1.0
# Name: Profit, dtype: float64

# %%
#corr=data_num.drop('Profit',axis=1).corr()
#sns.heatmap(corr[(corr>=0.5) | (corr<=-0.4)],
#           cmap='viridis',vmax=1.0,vmin=-1.0,linewidths=0.1,
#           annot=True,annot_kws={'size':8},square=True)

# %%
profit = list(data.Profit) 
plt.boxplot(profit) 
plt.show()

# %%
data.groupby(["Region"]).sum().sort_values("Profit", ascending=False)
# Out:
#          Postal Code        Sales  Quantity  Discount       Profit
# Region
# West       293739752  725457.8245     12266    350.20  108418.4489
# East        50171698  678781.2400     10618    414.00   91522.7800
# South       55875052  391721.9050      6209    238.55   46749.4303
# Central    151786150  501239.8908      8780    558.34   39706.3625

# %%
data.groupby(["Sub-Category"]).mean().sort_values("Discount", ascending=False)
# Out:
#                Postal Code        Sales  Quantity  Discount     Profit
# Sub-Category
# Binders       54908.994091   133.560560  3.922521  0.372292  19.843574
# Machines      55344.939130  1645.553313  3.826087  0.306087  29.432669
# Tables        58331.749216   648.794771  3.890282  0.261285 -55.565771
# ...                    ...          ...       ...       ...        ...
# Art           54434.243719    34.068834  3.768844  0.074874   8.200737
# Storage       54667.517730   264.590553  3.732861  0.074704  25.152277
# Labels        53716.991758    34.303055  3.846154  0.068681  15.236962
#
# [17 rows x 5 columns]

# %%
product_sorted
# Out:
#                     Profit
# Category
# Furniture         8.699327
# Office Supplies  20.327050
# Technology       78.752002

# %%
Category_sorted=pd.DataFrame(data.groupby('Category')['Profit'].mean().sort_values(ascending=True))
plt.figure(figsize=(9,6))
plt.xlabel('Profit')
plt.ylabel('Categories')
plt.title('Profit per category')
graph=plt.barh(np.arange(len(Category_sorted.index)),product_sorted['Profit'],color='blue',)

# Writing product names on bar
for bar,category in zip(graph,Category_sorted.index):
    plt.text(0.005,bar.get_y()+bar.get_width(),'{}'.format(category),va='center',fontsize=11,color='white')

# Writing polarity values on graph
for bar,profit in zip(graph,Category_sorted['Profit']):
  plt.text(bar.get_width()+0.001,bar.get_y()+bar.get_width(),'%.3f'%profit,va='center',fontsize=11,color='black')
  
plt.yticks([])
plt.show()

# %%
SubCategory_sorted=pd.DataFrame(data.groupby('Sub-Category')['Profit'].mean().sort_values(ascending=True))

# %%
SubCategory_sorted
# Out:
#                   Profit
# Sub-Category
# Tables        -55.565771
# Bookcases     -15.230509
# Supplies       -6.258418
# Fasteners       4.375660
# Art             8.200737
# Furnishings    13.645918
# Labels         15.236962
# Binders        19.843574
# Paper          24.856620
# Storage        25.152277
# Envelopes      27.418019
# Machines       29.432669
# Appliances     38.922758
# Chairs         43.095894
# Phones         50.073938
# Accessories    54.111788
# Copiers       817.909190

# %%
data.groupby('Sub-Category')['Discount'].mean().sort_values(ascending=True)
# Out:
# Sub-Category
# Labels         0.068681
# Storage        0.074704
# Art            0.074874
# Paper          0.074891
# Supplies       0.076842
# Accessories    0.078452
# Envelopes      0.080315
# Fasteners      0.082028
# Furnishings    0.138349
# Phones         0.154556
# Copiers        0.161765
# Appliances     0.166524
# Chairs         0.170178
# Bookcases      0.211140
# Tables         0.261285
# Machines       0.306087
# Binders        0.372292
# Name: Discount, dtype: float64

# %%
dataSC_mean=data.groupby('Sub-Category').mean()

# %%
dataSC=data.groupby('Sub-Category').sum()

# %%
QuanSum=dataSC['Quantity']

# %%
dataSC_mean
# Out:
#                Postal Code        Sales  Quantity  Discount      Profit
# Sub-Category
# Accessories   57378.624516   215.974604  3.840000  0.078452   54.111788
# Appliances    54185.703863   230.755710  3.710300  0.166524   38.922758
# Art           54434.243719    34.068834  3.768844  0.074874    8.200737
# Binders       54908.994091   133.560560  3.922521  0.372292   19.843574
# Bookcases     56015.521930   503.859633  3.807018  0.211140  -15.230509
# Chairs        56622.737439   532.332420  3.818476  0.170178   43.095894
# Copiers       56962.897059  2198.941618  3.441176  0.161765  817.909190
# Envelopes     52463.507874    64.867724  3.566929  0.080315   27.418019
# Fasteners     57631.626728    13.936774  4.211982  0.082028    4.375660
# Furnishings   54211.525601    95.825668  3.723093  0.138349   13.645918
# Labels        53716.991758    34.303055  3.846154  0.068681   15.236962
# Machines      55344.939130  1645.553313  3.826087  0.306087   29.432669
# ...

# %%
data2=dataSC_mean.drop(['Postal Code','Sales','Quantity'],axis=1)

# %%
data2['No.of Quantity']=QuanSum

# %%
data2.drop('Quantity',axis=1)
# Out:
#               Discount      Profit  No.of Quantity
# Sub-Category
# Accessories   0.078452   54.111788            2976
# Appliances    0.166524   38.922758            1729
# Art           0.074874    8.200737            3000
# Binders       0.372292   19.843574            5974
# Bookcases     0.211140  -15.230509             868
# Chairs        0.170178   43.095894            2356
# Copiers       0.161765  817.909190             234
# Envelopes     0.080315   27.418019             906
# Fasteners     0.082028    4.375660             914
# Furnishings   0.138349   13.645918            3563
# Labels        0.068681   15.236962            1400
# Machines      0.306087   29.432669             440
# Paper         0.074891   24.856620            5178
# Phones        0.154556   50.073938            3289
# Storage       0.074704   25.152277            3158
# Supplies      0.076842   -6.258418             647
# Tables        0.261285  -55.565771            1241

# %%
data.groupby(["State"]).mean().sort_values("Profit", ascending=False)
# Out:
#                  Postal Code       Sales  Quantity  Discount      Profit
# State
# Vermont          5408.000000  811.760909  4.545455  0.000000  204.088936
# Rhode Island     2908.535714  404.070643  3.553571  0.021429  130.100523
# Indiana         46923.503356  359.431946  3.879195  0.000000  123.375411
# ...                      ...         ...       ...       ...         ...
# North Carolina  28089.895582  223.305880  3.947791  0.283534  -30.083985
# Colorado        80295.758242  176.418231  3.807692  0.316484  -35.867351
# Ohio            43880.247335  166.861697  3.750533  0.324947  -36.186304
#
# [49 rows x 5 columns]

# %%
data.groupby(["Region"]).sum()
# Out:
#          Postal Code        Sales  Quantity  Discount       Profit
# Region
# Central    151786150  501239.8908      8780    558.34   39706.3625
# East        50171698  678781.2400     10618    414.00   91522.7800
# South       55875052  391721.9050      6209    238.55   46749.4303
# West       293739752  725457.8245     12266    350.20  108418.4489

# %%
pricePerProduct=data.groupby('Sub-Category').sum().sort_values('Profit',ascending=True)
pricePerProduct['Prices']=pricePerProduct['Sales']/pricePerProduct['Quantity']

# %%
pricePerProduct[:5]
# Out:
#               Postal Code        Sales  Quantity  Discount      Profit  \
# Sub-Category
# Tables           18607828  206965.5320      1241     83.35 -17725.4811
# Bookcases        12771539  114879.9963       868     48.14  -3472.5560
# Supplies         10633558   46673.5380       647     14.60  -1189.0995
# Fasteners        12506063    3024.2800       914     17.80    949.5182
# Machines          6364668  189238.6310       440     35.20   3384.7569
#
#                   Prices
# Sub-Category
# Tables        166.773193
# Bookcases     132.350226
# Supplies       72.138389
# Fasteners       3.308840
# Machines      430.087798

# %%
group=data.groupby(['Region','Sub-Category']).sum()

# %%
group
# Out:
#                       Postal Code      Sales  Quantity  Discount     Profit  \
# Region  Sub-Category
# Central Accessories      12032930  33956.076       716      22.8  7251.6306
#         Appliances        7921061  23582.033       470      55.2 -2638.6175
#         Art              11339924   5765.340       678      21.6  1195.1591
# ...                           ...        ...       ...       ...        ...
# West    Storage          24337808  70532.852      1039       8.2  8645.3222
#         Supplies          6341984  18127.122       238       2.6   626.0465
#         Tables           10669468  84754.562       481      23.2  1482.6073
#
#                       Prices
# Region  Sub-Category
# Central Accessories      0.0
#         Appliances       0.0
#         Art              0.0
# ...                      ...
# West    Storage          0.0
#         Supplies         0.0
#         Tables           0.0
#
# [68 rows x 6 columns]

# %%
total_price=group['Profit'].groupby(level=0,group_keys=False)
total_price.nlargest(5)
# Out:
# Region   Sub-Category
# Central  Copiers         15608.8413
#          Phones          12323.0267
#          Accessories      7251.6306
#                             ...
# West     Binders         16096.8016
#          Paper           12119.2364
#          Phones           9110.7426
# Name: Profit, Length: 20, dtype: float64

# %%
total_price.nlargest(10).plot(kind='bar', figsize=(15,5))
plt.title("products with region")
plt.ylabel('Profit')
plt.xlabel('Make');

# %%
data['Category'].value_counts().plot.pie(figsize=(6, 6), autopct='%.2f')
plt.title("Category wise pie chart")
# Out:
# Text(0.5, 1.0, 'Category wise pie chart')

# %%
corr = data.corr()
sns.set_context("notebook", font_scale=1.0, rc={"lines.linewidth": 2.5})
plt.figure(figsize=(13,7))
a = sns.heatmap(corr, annot=True, fmt='.2f')
rotx = a.set_xticklabels(a.get_xticklabels(), rotation=90)
roty = a.set_yticklabels(a.get_yticklabels(), rotation=30)

# %%
g = sns.lmplot('Discount',"Quantity", pricePerProduct);
